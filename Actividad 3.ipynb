# %%
# %ls
# Out:
#  00_00_binder.ipynb                    'Clase 4 nov gestion datos.ipynb'
#  00_00_primer_pasos.ipynb              'Clase 8 nov.ipynb'
#  01_01_data_types.ipynb                'Clase 8 nov pt2.ipynb'
#  01_02_read_iloc_unique_groupby.ipynb   datasets/
#  02_00_data_wrangling.ipynb             README.md
#  02_01_null_display.ipynb               requirements.txt
#  02_02_basic_math.ipynb                'Tabla pivote.ipynb'
#  antropometria-dataset.csv

# %%
import pandas as pd
import numpy as np

# %%
# %ls datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
df = pd.read_csv('antropometria-dataset.csv')
df.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
df.columns
# Out:
# Index(['folio', 'intp', 'entidad', 'desc_ent', 'sexo', 'edad', 'meses', 'peso',
#        'ropa', 'talla', 'emb', 'temb', 'cintura', 'cadera', 'sistol',
#        'diastol', 'hpresion', 'tbrazo', 'htension', 'PrimaryLast', 'code_upm',
#        'est_dis', 'est_urb', 'est_marg', 'pondef', 'est_var'],
#       dtype='object')

# %%
my_pivot = pd.pivot_table(df,
                          index = 'desc_ent',
                          values = 'peso',
                          aggfunc = 'mean',#['sum','median']
                          #columns = 'REG',
                          #margins = True #Margin crea una nueva columna que suma todo
                         )
my_pivot
# Out:
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# OAXACA                           58.800067
# ...

# %%
my_pivot_2 = pd.pivot_table(df,
                          index = 'desc_ent',
                          values = 'peso',
                          aggfunc = 'mean',#['sum','median']
                          columns = 'sexo',
                          #margins = True #Margin crea una nueva columna que suma todo
                         )
my_pivot_2
# Out:
# sexo                                     1          2
# desc_ent
# AGUASCALIENTES                   69.985381  63.254292
# BAJA CALIFORNIA                  71.391818  65.893667
# BAJA CALIFORNIA SUR              75.561015  68.168959
# CAMPECHE                         68.622637  62.920493
# CHIAPAS                          58.365222  57.096111
# CHIHUAHUA                        68.892642  64.815295
# COAHUILA DE ZARAGOZA             68.873094  67.467348
# COLIMA                           70.998878  66.978393
# DISTRITO FEDERAL                 69.460661  61.654128
# DURANGO                          68.846451  64.400031
# GUANAJUATO                       65.008000  63.100995
# GUERRERO                         62.611437  58.899850
# HIDALGO                          61.747958  58.972554
# JALISCO                          67.076482  66.418111
# MEXICO                           63.140314  58.887882
# MICHOACAN DE OCAMPO              66.374612  63.784311
# ...

# %% [markdown]
# # Archivo Adults
# ### Profesor algunos incisos sobre este archivo los contesté desde Excel pensando que era por ese medio, de igual forma
# ### las siguientes lineas de código son para contestar algunas de las perguntas del quizz. Gracias!

# %%
import pandas as pd
import numpy as np

# %%
path = 'datasets/adult.csv'
ndf = pd.read_csv(path)
ndf.head(3)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
#
#         marital-status          occupation    relationship    race    sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# 0          2174             0              40   United-States     <=50K
# 1             0             0              13   United-States     <=50K
# 2             0             0              40   United-States     <=50K

# %%
ndf.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'the label'],
#       dtype='object')

# %%
new_pivot = pd.pivot_table(ndf,
                          index = ['education','marital-status'],
                          values = 'age',
                          aggfunc = 'median',#['sum','median']
                          columns = 'sex',
                          #margins = True #Margin crea una nueva columna que suma todo
                         )
new_pivot
# Out:
# sex                                    Female   Male
# education     marital-status
#  10th          Divorced                  45.0   39.0
#                Married-civ-spouse        32.0   48.0
#                Married-spouse-absent     39.0   49.0
#                Never-married             18.0   20.0
#                Separated                 34.0   38.0
# ...                                       ...    ...
#  Some-college  Married-civ-spouse        38.0   42.0
#                Married-spouse-absent     31.0   37.0
#                Never-married             22.0   23.0
#                Separated                 38.0   37.0
#                Widowed                   58.0   60.5
#
# [103 rows x 2 columns]

# %%
#La siguiente linea de código la investigué en internet dado que no me desplegaban 
#todas las lineas de la tabla pivote para conocer el valor que el quizz de canvas me pedía.

pd.set_option('display.max_rows', None) 
print(new_pivot)
# Out:
# sex                                    Female   Male
# education     marital-status
#  10th          Divorced                  45.0   39.0
#                Married-civ-spouse        32.0   48.0
#                Married-spouse-absent     39.0   49.0
#                Never-married             18.0   20.0
#                Separated                 34.0   38.0
#                Widowed                   60.0   57.0
#  11th          Divorced                  41.0   38.0
#                Married-civ-spouse        42.0   41.0
#                Married-spouse-absent     30.0   32.5
#                Never-married             18.0   18.0
#                Separated                 35.5   34.5
#                Widowed                   56.0   60.0
#  12th          Divorced                  41.0   41.0
#                Married-civ-spouse        34.0   41.5
#                Married-spouse-absent     25.5   46.0
#                Never-married             18.0   20.5
# ...
