# %% [markdown]
# <h1> Gestión de datos (nov 4)

# %%
# %ls datasets
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       sample_pivot.csv
# Book3.csv                  headbrain.csv  tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx

# %%
import pandas as pd

# %% [markdown]
# # **Leer archivo** e **imprimir el header con las 3 lineas**

# %%
path = 'datasets/Cartwheeldata.csv'
df = pd.read_csv(path)
df.head(3)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7

# %%
#Ver las columnas
x = df.columns
x
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
type(x)
# Out:
# pandas.core.indexes.base.Index

# %%
x = list(df.columns)
print(x)
type(x)
# Out:
# ['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup', 'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup', 'Score']
# list

# %%
x.sort()
x
# Out:
# ['Age',
#  'CWDistance',
#  'Complete',
#  'CompleteGroup',
#  'Gender',
#  'GenderGroup',
#  'Glasses',
#  'GlassesGroup',
#  'Height',
#  'ID',
#  'Score',
#  'Wingspan']

# %% [markdown]
# ## Seleccionar variables de interes

# %%
#Usar 'iloc' y 'loc'

# %%
df.columns
# Out:
# Index(['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses', 'GlassesGroup',
#        'Height', 'Wingspan', 'CWDistance', 'Complete', 'CompleteGroup',
#        'Score'],
#       dtype='object')

# %%
x = df['Age'].head(2)
print(x)
type(x)
# Out:
# 0    56
# 1    26
# Name: Age, dtype: int64
# pandas.core.series.Series

# %%
df[['Age', 'Height']].head(2)
# Out:
#    Age  Height
# 0   56    62.0
# 1   26    62.0

# %%
z = df[['Age', 'Height', 'CWDistance']].head(2)
z
# Out:
#    Age  Height  CWDistance
# 0   56    62.0          79
# 1   26    62.0          70

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['ID', 'Age', 'Gender', 'GenderGroup', 'Glasses']].head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 0   1   56      F            1       Y
# 1   2   26      F            1       Y

# %% [markdown]
# ## La sintaxis de loc:
# ## [row_initial:row_final, col_initial:col_final]

# %%
#NOMBRES DE LAS COLUMNAS 

#df contiene TODAS las columnas del csv. Estas estan ordenadas
#SORT( line 22 ) 
newdf = df.loc[:, :'Glasses']
newdf.head(4)
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 0   1   56      F            1       Y
# 1   2   26      F            1       Y
# 2   3   33      F            1       Y
# 3   4   39      F            1       N

# %% [markdown]
# ## Sintáxis de iloc es
# ## [row_initial:row_final, col_initial:col_final]

# %%
#INDICES DE LOS RENGLONES Y LAS COLUMNAS

# %%
ndf = df.iloc[3:5, :5]
ndf
# Out:
#    ID  Age Gender  GenderGroup Glasses
# 3   4   39      F            1       N
# 4   5   27      M            2       N
