# %% [markdown]
# # Clase Jueves 4 de Noviembre

# %% [markdown]
# # Páginas para programar python

# %%
import numpy as np

# %%
import math

# %%
print(math.pi)

# %%
type(math.pi)

# %% [markdown]
# **Listas**

# %%
import math

# %%
una_lista = [1, 3/5,'nombre', math.pi, True, 5<=3, 1==3, 3==3, None]

# %%
una_lista

# %%
str_list = ['zeroth','first', 'second', 'third', 'fourth', 'fifth', 'sixth']
str_list

# %%
str_list.sort()
str_list

# %%
str_list.sort(reverse=True)
str_list

# %%
str_list.sort()
str_list

# %%
numbers = [11,20,3,14,53,61]

# %%
numbers[0]

# %%
numbers[:3]

# %%
numbers[::]

# %% [markdown]
# _Imprimir todos los números en sentido contrario_

# %%
numbers[::-1]

# %%
numbers[-3:]

# %%
x = sum(numbers)
x

# %%
y = len(numbers)
y

# %%
promedio = x/y
promedio

# %% [markdown]
# <h1>un loop "for"

# %%
numbers
# Out:
# [11, 20, 3, 14, 53, 61]

# %%
for i in numbers:
    print(i, '\t\t', type(i))
# Out:
# 11 		 <class 'int'>
# 20 		 <class 'int'>
# 3 		 <class 'int'>
# 14 		 <class 'int'>
# 53 		 <class 'int'>
# 61 		 <class 'int'>

# %%
x = 6
y = 1
if x < y: 
    print(' {} es menor que {} '.format(x,y))
else: 
    print(' {} es mayor que {}'.format(x,y))
# Out:
#  6 es mayor que 1
